# %% [markdown]
# ## Python Excel

# %%
import xlrd

# %%
wb = xlrd.open_workbook_xls('eir_June2021.xlsx')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-4-ce4fc70c0621> in <module>
# ----> 1 wb = xlrd.open_workbook_xls('eir_June2021.xlsx')
#
# /opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows, ignore_workbook_corruption)
#      77         t1 = perf_counter()
#      78         bk.load_time_stage_1 = t1 - t0
# ---> 79         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      80         if not biff_version:
#      81             raise XLRDError("Can't determine file's BIFF version")
#
# /opt/anaconda3/lib/python3.8/site-packages/xlrd/book.py in getbof(self, rqd_stream)
#    1282             bof_error('Expected BOF record; met end of file')
#    1283         if opcode not in bofcodes:
# ...

# %%
import pandas as pd

# %%
pd.ExcelFile('eir_June2021.xlsx').sheet_names
# Out:
# ['Indian Companies', 'LLP Companies', 'Foriegn Companies']

# %%
wb = pd.ExcelFile('eir_June2021.xlsx')

# %%
wb.parse()
# Out:
#                          CIN  \
# 0      U67100MP2021PTC056407
# 1      U17299WB2021PTC245826
# 2      U45209DL2021PTC382687
# 3      U74999KA2021PTC148125
# 4      U92419TG2021PTC152397
# ...                      ...
# 12716  U01110BR2021PTC052652
# 12717  U72900AP2021PTC118695
# 12718  U63022MH2021PTC363220
# 12719  U92114MP2021OPC056533
# 12720  U45201PN2021PTC202314
#
#                                             COMPANY NAME DATE OF REGISTRATION  \
# 0                       JKG INVESTMENTS PRIVATE LIMITED            2021-06-24
# 1               MAMAN MUSE MANUFACTURER PRIVATE LIMITED            2021-06-16
# 2                       I S F ENGINEERS PRIVATE LIMITED            2021-06-24
# 3       ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED           2021-06-03
# 4                          DREAM BEHIND PRIVATE LIMITED            2021-06-21
# ...                                                  ...                  ...
# ...

# %%
type(wb.parse())
# Out:
# pandas.core.frame.DataFrame

# %%
df = wb.parse()

# %%
df
# Out:
#                          CIN  \
# 0      U67100MP2021PTC056407
# 1      U17299WB2021PTC245826
# 2      U45209DL2021PTC382687
# 3      U74999KA2021PTC148125
# 4      U92419TG2021PTC152397
# ...                      ...
# 12716  U01110BR2021PTC052652
# 12717  U72900AP2021PTC118695
# 12718  U63022MH2021PTC363220
# 12719  U92114MP2021OPC056533
# 12720  U45201PN2021PTC202314
#
#                                             COMPANY NAME DATE OF REGISTRATION  \
# 0                       JKG INVESTMENTS PRIVATE LIMITED            2021-06-24
# 1               MAMAN MUSE MANUFACTURER PRIVATE LIMITED            2021-06-16
# 2                       I S F ENGINEERS PRIVATE LIMITED            2021-06-24
# 3       ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED           2021-06-03
# 4                          DREAM BEHIND PRIVATE LIMITED            2021-06-21
# ...                                                  ...                  ...
# ...

# %%
df.head()
# Out:
#                      CIN                                      COMPANY NAME  \
# 0  U67100MP2021PTC056407                  JKG INVESTMENTS PRIVATE LIMITED
# 1  U17299WB2021PTC245826          MAMAN MUSE MANUFACTURER PRIVATE LIMITED
# 2  U45209DL2021PTC382687                  I S F ENGINEERS PRIVATE LIMITED
# 3  U74999KA2021PTC148125  ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED
# 4  U92419TG2021PTC152397                     DREAM BEHIND PRIVATE LIMITED
#
#   DATE OF REGISTRATION MONTH NAME           STATE            ROC  \
# 0           2021-06-24 2021-06-01  Madhya Pradesh    RoC-Gwalior
# 1           2021-06-16 2021-06-01     West Bengal    RoC-Kolkata
# 2           2021-06-24 2021-06-01           Delhi      RoC-Delhi
# 3           2021-06-03 2021-06-01       Karnataka  RoC-Bangalore
# 4           2021-06-21 2021-06-01       Telangana  RoC-Hyderabad
#
#   COMPANY STATUS                   CATEGORY    CLASS      COMPANY TYPE  \
# ...

# %%
pd.DataFrame({'Yes':[20, 40, 10], 'No':[12, 21, 18]})
# Out:
#    Yes  No
# 0   20  12
# 1   40  21
# 2   10  18

# %%
pd.Series(['a', 'b', 'c','ad'])
# Out:
# 0     a
# 1     b
# 2     c
# 3    ad
# dtype: object

# %%
df.shape
# Out:
# (12721, 16)

# %%
df.EMAIL
# Out:
# 0            compliance@gujralhotels.com
# 1        mamanmusemanufacturer@gmail.com
# 2                     is.irfan@gmail.com
# 3                  shreyas.m92@gmail.com
# 4                  shabbir.msp@gmail.com
#                       ...
# 12716         kumarisamtasinha@gmail.com
# 12717     ramalingeswaraittech@gmail.com
# 12718          YASHODEEP.BAFNA@GMAIL.COM
# 12719       er.ankitmittal2009@gmail.com
# 12720       prasadhawaldar1001@gmail.com
# Name: EMAIL, Length: 12721, dtype: object

# %%
df['EMAIL']
# Out:
# 0            compliance@gujralhotels.com
# 1        mamanmusemanufacturer@gmail.com
# 2                     is.irfan@gmail.com
# 3                  shreyas.m92@gmail.com
# 4                  shabbir.msp@gmail.com
#                       ...
# 12716         kumarisamtasinha@gmail.com
# 12717     ramalingeswaraittech@gmail.com
# 12718          YASHODEEP.BAFNA@GMAIL.COM
# 12719       er.ankitmittal2009@gmail.com
# 12720       prasadhawaldar1001@gmail.com
# Name: EMAIL, Length: 12721, dtype: object

# %%
df['EMAIL'][0]
# Out:
# 'compliance@gujralhotels.com'

# %%
df['EMAIL'][0:10]
# Out:
# 0        compliance@gujralhotels.com
# 1    mamanmusemanufacturer@gmail.com
# 2                 is.irfan@gmail.com
# 3              shreyas.m92@gmail.com
# 4              shabbir.msp@gmail.com
# 5            nikhilaroraet@gmail.com
# 6               pavanraj89@gmail.com
# 7          Suneet.Kaul@sybarisip.com
# 8        ritishvenkat.jogi@gmail.com
# 9    Nagaraj.Kulkarni@compegence.com
# Name: EMAIL, dtype: object

# %%
# [row_slicing, column_slicing]
df.iloc[:]
# Out:
#                          CIN  \
# 0      U67100MP2021PTC056407
# 1      U17299WB2021PTC245826
# 2      U45209DL2021PTC382687
# 3      U74999KA2021PTC148125
# 4      U92419TG2021PTC152397
# ...                      ...
# 12716  U01110BR2021PTC052652
# 12717  U72900AP2021PTC118695
# 12718  U63022MH2021PTC363220
# 12719  U92114MP2021OPC056533
# 12720  U45201PN2021PTC202314
#
#                                             COMPANY NAME DATE OF REGISTRATION  \
# 0                       JKG INVESTMENTS PRIVATE LIMITED            2021-06-24
# 1               MAMAN MUSE MANUFACTURER PRIVATE LIMITED            2021-06-16
# 2                       I S F ENGINEERS PRIVATE LIMITED            2021-06-24
# 3       ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED           2021-06-03
# 4                          DREAM BEHIND PRIVATE LIMITED            2021-06-21
# ...                                                  ...                  ...
# ...

# %%
df.iloc[0:4, 1:5]
# Out:
#                                        COMPANY NAME DATE OF REGISTRATION  \
# 0                  JKG INVESTMENTS PRIVATE LIMITED            2021-06-24
# 1          MAMAN MUSE MANUFACTURER PRIVATE LIMITED            2021-06-16
# 2                  I S F ENGINEERS PRIVATE LIMITED            2021-06-24
# 3  ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED           2021-06-03
#
#   MONTH NAME           STATE
# 0 2021-06-01  Madhya Pradesh
# 1 2021-06-01     West Bengal
# 2 2021-06-01           Delhi
# 3 2021-06-01       Karnataka

# %%
df.iloc[0:4, -5:]
# Out:
#    PAIDUP CAPITAL  ACTIVITY CODE      ACTIVITY DESCRIPTION  \
# 0          100000          67100                   Finance
# 1          100000          17299  Manufacturing (Textiles)
# 2         6000000          45209              Construction
# 3          100000          74999         Business Services
#
#                         REGISTERED OFFICE ADDRESS  \
# 0                  434/6, Ratan Colony, Gorakhpur
# 1       Plot No. - 76, Sahebkhan KeranibarSatmile
# 2   R-248 G/F GALI NO 4JOGA BAI EXTN. JAMIA NAGAR
# 3  #1005 C, Dr RAJKUMAR ROAD4TH BLOCK RAJAJINAGAR
#
#                              EMAIL
# 0      compliance@gujralhotels.com
# 1  mamanmusemanufacturer@gmail.com
# 2               is.irfan@gmail.com
# 3            shreyas.m92@gmail.com

# %%
df.iloc[0:4, [1, -3, -1]]
# Out:
#                                        COMPANY NAME      ACTIVITY DESCRIPTION  \
# 0                  JKG INVESTMENTS PRIVATE LIMITED                    Finance
# 1          MAMAN MUSE MANUFACTURER PRIVATE LIMITED   Manufacturing (Textiles)
# 2                  I S F ENGINEERS PRIVATE LIMITED               Construction
# 3  ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED         Business Services
#
#                              EMAIL
# 0      compliance@gujralhotels.com
# 1  mamanmusemanufacturer@gmail.com
# 2               is.irfan@gmail.com
# 3            shreyas.m92@gmail.com

# %%
# [row_slicing, column_names]
df.loc[0:4, ['COMPANY NAME', 'ACTIVITY DESCRIPTION', 'EMAIL']]
# Out:
#                                        COMPANY NAME  \
# 0                  JKG INVESTMENTS PRIVATE LIMITED
# 1          MAMAN MUSE MANUFACTURER PRIVATE LIMITED
# 2                  I S F ENGINEERS PRIVATE LIMITED
# 3  ADM NORTHFIELD ENTERPRISES INDIA PRIVATE LIMITED
# 4                     DREAM BEHIND PRIVATE LIMITED
#
#                     ACTIVITY DESCRIPTION                            EMAIL
# 0                                Finance      compliance@gujralhotels.com
# 1               Manufacturing (Textiles)  mamanmusemanufacturer@gmail.com
# 2                           Construction               is.irfan@gmail.com
# 3                      Business Services            shreyas.m92@gmail.com
# 4  Community, personal & Social Services            shabbir.msp@gmail.com

# %%
df['EMAIL']
# Out:
# 0            compliance@gujralhotels.com
# 1        mamanmusemanufacturer@gmail.com
# 2                     is.irfan@gmail.com
# 3                  shreyas.m92@gmail.com
# 4                  shabbir.msp@gmail.com
#                       ...
# 12716         kumarisamtasinha@gmail.com
# 12717     ramalingeswaraittech@gmail.com
# 12718          YASHODEEP.BAFNA@GMAIL.COM
# 12719       er.ankitmittal2009@gmail.com
# 12720       prasadhawaldar1001@gmail.com
# Name: EMAIL, Length: 12721, dtype: object

# %%
df['EMAIL'][:10]
# Out:
# 0        compliance@gujralhotels.com
# 1    mamanmusemanufacturer@gmail.com
# 2                 is.irfan@gmail.com
# 3              shreyas.m92@gmail.com
# 4              shabbir.msp@gmail.com
# 5            nikhilaroraet@gmail.com
# 6               pavanraj89@gmail.com
# 7          Suneet.Kaul@sybarisip.com
# 8        ritishvenkat.jogi@gmail.com
# 9    Nagaraj.Kulkarni@compegence.com
# Name: EMAIL, dtype: object

# %%
for a in df['EMAIL'][:10]:
    print(a)
# Out:
# compliance@gujralhotels.com
# mamanmusemanufacturer@gmail.com
# is.irfan@gmail.com
# shreyas.m92@gmail.com
# shabbir.msp@gmail.com
# nikhilaroraet@gmail.com
# pavanraj89@gmail.com
# Suneet.Kaul@sybarisip.com
# ritishvenkat.jogi@gmail.com
# Nagaraj.Kulkarni@compegence.com

# %%
email_lst = []
for a in df['EMAIL'][:50]:
    a.lower()
    email_lst.append(a)

# %%
'sadSA'.lower()
# Out:
# 'sadsa'

# %%
email_lst
# Out:
# ['compliance@gujralhotels.com',
#  'mamanmusemanufacturer@gmail.com',
#  'is.irfan@gmail.com',
#  'shreyas.m92@gmail.com',
#  'shabbir.msp@gmail.com',
#  'nikhilaroraet@gmail.com',
#  'pavanraj89@gmail.com',
#  'Suneet.Kaul@sybarisip.com',
#  'ritishvenkat.jogi@gmail.com',
#  'Nagaraj.Kulkarni@compegence.com',
#  'jagadeesh.kancharana@gmail.com',
#  'srdnmail@gmail.com',
#  'admin@vakilgiri.com',
#  'info.kalakartindia@gmail.com',
#  'lendveusha@gmail.com',
#  'surakshabio.mrp@gmail.com',
#  'sk86915n@gmail.com',
#  'casagarreddyn@gmail.com',
#  'singlamanish54@gmail.com',
#  'infofinefeelsecurecompany@gmail.com',
#  'caretoindia@gmail.com',
#  'ksbabu.ksb@gmail.com',
#  'RITUS1293@GMAIL.COM',
#  'redcarpetsport@outlook.com',
#  'maheshsharma686@gmail.com',
#  'marketing@walterpharmaceuticals.com',
#  'Info@myhomeego.com',
#  'mddesk@skandhanshi.com',
#  'Reveredmedia.in@gmail.com',
#  'amoltope@gmail.com',
#  'laxlingam@gmail.com',
#  'aquablueresortpvtltd@gmail.com',
# ...

# %%
email_str = ', '.join(email_lst)

# %%
email_str
# Out:
# 'compliance@gujralhotels.com, mamanmusemanufacturer@gmail.com, is.irfan@gmail.com, shreyas.m92@gmail.com, shabbir.msp@gmail.com, nikhilaroraet@gmail.com, pavanraj89@gmail.com, Suneet.Kaul@sybarisip.com, ritishvenkat.jogi@gmail.com, Nagaraj.Kulkarni@compegence.com, jagadeesh.kancharana@gmail.com, srdnmail@gmail.com, admin@vakilgiri.com, info.kalakartindia@gmail.com, lendveusha@gmail.com, surakshabio.mrp@gmail.com, sk86915n@gmail.com, casagarreddyn@gmail.com, singlamanish54@gmail.com, infofinefeelsecurecompany@gmail.com, caretoindia@gmail.com, ksbabu.ksb@gmail.com, RITUS1293@GMAIL.COM, redcarpetsport@outlook.com, maheshsharma686@gmail.com, marketing@walterpharmaceuticals.com, Info@myhomeego.com, mddesk@skandhanshi.com, Reveredmedia.in@gmail.com, amoltope@gmail.com, laxlingam@gmail.com, aquablueresortpvtltd@gmail.com, indo.jigar@gmail.com, pranarupaajay@gmail.com, appicoderssoftwarepvtltd@gmail.com, madhura@shopwocbeauty.com, haappyherbs@gmail.com, suryavanshicg@gmail.com, nageshhalgare
# ...

# %%
email_str.lower()
# Out:
# 'compliance@gujralhotels.com, mamanmusemanufacturer@gmail.com, is.irfan@gmail.com, shreyas.m92@gmail.com, shabbir.msp@gmail.com, nikhilaroraet@gmail.com, pavanraj89@gmail.com, suneet.kaul@sybarisip.com, ritishvenkat.jogi@gmail.com, nagaraj.kulkarni@compegence.com, jagadeesh.kancharana@gmail.com, srdnmail@gmail.com, admin@vakilgiri.com, info.kalakartindia@gmail.com, lendveusha@gmail.com, surakshabio.mrp@gmail.com, sk86915n@gmail.com, casagarreddyn@gmail.com, singlamanish54@gmail.com, infofinefeelsecurecompany@gmail.com, caretoindia@gmail.com, ksbabu.ksb@gmail.com, ritus1293@gmail.com, redcarpetsport@outlook.com, maheshsharma686@gmail.com, marketing@walterpharmaceuticals.com, info@myhomeego.com, mddesk@skandhanshi.com, reveredmedia.in@gmail.com, amoltope@gmail.com, laxlingam@gmail.com, aquablueresortpvtltd@gmail.com, indo.jigar@gmail.com, pranarupaajay@gmail.com, appicoderssoftwarepvtltd@gmail.com, madhura@shopwocbeauty.com, haappyherbs@gmail.com, suryavanshicg@gmail.com, nageshhalgare
# ...

# %%
email_lst = []
for a in df['EMAIL'][250:350]:
    a.lower()
    email_lst.append(a)

email_str = ', '.join(email_lst)
email_str.lower()
# Out:
# 'mulgi.vinodkumar@gmail.com, admin@tamilarasi.com, shankar.avhad@rediffmail.com, preranasinghal321@gmail.com, cakeshavagarwal@outlook.com, narayanbhai0072@gmail.com, arjun.pola@gmail.com, sushilarathee001@gmail.com, dk9648462134@gmail.com, abidmg@gmail.com, mohantybikram.mo@gmail.com, support@meraprofit.com, yasinmalik511@gmail.com, hhusseini13@gmail.com, shreegajananempire@gmail.com, bpkhillare2205@gmail.com, raveesh.singhal2@gmail.com, skolsur@gmail.com, filingezee@gmail.com, stayzyhygiene@gmail.com, vinodkangen@gmail.com, manoj.alishan@gmail.com, support@meraprofit.com, vashishta.sap@gmail.com, hejibsachin@gmail.com, pancumbum@gmail.com, admin@vakilgiri.com, info@vatvriksham.in, kumarvasantvasantkumar@gmail.com, admin@vakilgiri.com, ramitmam@gmail.com, angshuman.chetia89@gmail.com, rbaclt@gmail.com, arindam.paul74@gmail.com, grameenfirst.ebf@gmail.com, shaadkhan026@gmail.com, vermakaveri18@gmail.com, cfo@muruganidlishop.com, anil@indcoat.com, mahaveerbalajihospital@gmail.com, maha
# ...

# %%
df2 = pd.read_csv('UttarPradesh.csv', low_memory=False)

# %%
df2.head()
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER  \
# 0           L01112UP1989PLC011004
# 1           L01131UP1980PLC004984
# 2           L01406UP1969PLC003268
# 3           L02001UP1998PLC023984
# 4           L14101UP1977PLC021546
#
#                                       Company_Name             Company_status  \
# 0  SHRI GANG INDUSTRIES AND ALLIEDPRODUCTS LIMITED                     Active
# 1                            BANARAS BEADS LIMITED                     Active
# 2          J K SATOH AGRICULTURAL MACHINES LIMITED  Dormant under section 455
# 3                           SPARK UNIGLOBE LIMITED                Amalgamated
# 4                              ORIENT BELL LIMITED                     Active
#
#   Company_class           Company_Category Company_sub_category  \
# 0        Public  Company limited by Shares     Non-govt company
# 1        Public  Company limited by Shares     Non-govt company
# 2        Public  Company limited by Shares     Non-govt company
# ...

# %%
df.values
# Out:
# array([['U67100MP2021PTC056407', 'JKG INVESTMENTS PRIVATE LIMITED ',
#         Timestamp('2021-06-24 00:00:00'), ..., 'Finance',
#         '434/6, Ratan Colony, Gorakhpur', 'compliance@gujralhotels.com'],
#        ['U17299WB2021PTC245826',
#         'MAMAN MUSE MANUFACTURER PRIVATE LIMITED ',
#         Timestamp('2021-06-16 00:00:00'), ...,
#         'Manufacturing (Textiles)',
#         'Plot No. - 76, Sahebkhan KeranibarSatmile',
#         'mamanmusemanufacturer@gmail.com'],
#        ['U45209DL2021PTC382687', 'I S F ENGINEERS PRIVATE LIMITED ',
#         Timestamp('2021-06-24 00:00:00'), ..., 'Construction',
#         'R-248 G/F GALI NO 4JOGA BAI EXTN. JAMIA NAGAR',
#         'is.irfan@gmail.com'],
#        ...,
#        ['U63022MH2021PTC363220', 'ANITA S PIPADA PRIVATE LIMITED ',
#         Timestamp('2021-06-08 00:00:00'), ...,
#         'Transport, storage and Communications', '2043, SAKURISAKURI',
#         'YASHODEEP.BAFNA@GMAIL.COM'],
#        ['U92114MP2021OPC056533',
# ...

# %%
import time
t1 = time.time()
for value in df.values:
    print(value[0])
    
t2 = time.time()

print(t2-t1)
# Out:
# U67100MP2021PTC056407
# U17299WB2021PTC245826
# U45209DL2021PTC382687
# U74999KA2021PTC148125
# U92419TG2021PTC152397
# U80301MP2021PTC056464
# U74999KA2021PTC148526
# U74999HR2021PTC095722
# U34300TG2021PTC152513
# U72900KA2021PTC148275
# U74999AP2021PTC118486
# U45209TG2021PTC152025
# U72900JH2021PTC016668
# U74999UP2021PTC147081
# U55209PN2021PTC201849
# U74999TG2021PTC152134
# U51909GJ2021PTC123185
# U74999TG2021PTC152421
# U27109HR2021PTC095503
# U17299UP2021PTC146722
# U85300KA2021NPL148160
# U52609TN2021PTC143830
# U72900BR2021PTC052559
# U51909UP2021OPC147742
# U50400RJ2021PTC075328
# U24299HR2021PTC095940
# U74999KA2021PTC148904
# U36999TG2021PTC152345
# U74999DL2021PTC382219
# U74999PN2021PTC201655
# U52390TN2021PTC144052
# U55209WB2021PTC245639
# U41000GJ2021PTC123395
# U15400TG2021PTC152153
# U72200DL2021PTC382416
# U24290MH2021PTC362318
# U24241TN2021PTC143842
# U24100CT2021PTC011649
# U15121MH2021PTC362055
# U72900DL2021PTC382744
# U24239MP2021PTC056428
# ...

# %%
s = "https://www.amazon.in/HP-Processor-39-62cms-i3-1115G4-15s-du3038TU/dp/B08S3MGDS3/"

# %%
len(s)
# Out:
# 81

# %%
s = "https://www.amazon.in/HP-Processor-39-62cms-i3-1115G4-15s-du3038TU/dp/B08S3MGDS3/?_encoding=UTF8&pd_rd_w=LFhd9&pf_rd_p=6aeb164c-387d-440e-8808-65edf45c4683&pf_rd_r=TDG0D4MGXM0E1DJ428BV&pd_rd_r=807713bd-d23f-4fd7-9cea-5adc8335a8fc&pd_rd_wg=ZGHre&ref_=pd_gw_ci_mcx_mr_hp_atf_m"

# %%
len(s)
# Out:
# 274
